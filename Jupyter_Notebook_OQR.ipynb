# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# Exercise 2: ![Ex. 2.png](attachment:85091505-3cd2-45e4-bc37-61c2a76b39cf.png)

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# Exercise 3: ![Ex. 3.png](attachment:f6c67ee0-5d2b-46be-af11-e59488704edf.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Exercise 10: ![Ex. 10.png](attachment:c7ff6e5f-778b-49c2-a5aa-f4686ceb57f7.png)

# %% [markdown]
# Objectives:
# - List of popular languages for Data Science.
# - Libraries for Data Science.
# - Cloud-based tools for Data Science.
# - IDEs.

# %% [markdown]
# Exercise 4: ![Ex. 4.png](attachment:21a4ab78-b272-4966-9666-0cc900b6df1e.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python.
# 2. R.
# 3. SQL.

# %% [markdown]
# Exercise 5: ![Ex. 5.png](attachment:2c397810-3068-4861-a21c-81ae0aa85005.png)

# %% [markdown]
# Some of the commonly used libraries by Data Scientists include:
# - dplyr.
# - strigr.
# - ggplot2.
# - caret.

# %% [markdown]
# Exercise 6: ![Ex. 6.png](attachment:bc75c121-5605-4a78-9634-0a27c422ad11.png)

# %% [markdown]
# # Data Science Tools
# - Jupyter notebook.
# - Spyder.
# - RStudio.

# %% [markdown]
# Exercise 7: ![Ex. 7.png](attachment:4cd76698-7986-480b-9af9-962c98796bd0.png)

# %% [markdown]
# ### Below are a few examples evaluating arithmetic expressions in Python

# %% [markdown]
# Exercise 8: ![Ex. 8.png](attachment:6a741ab2-a5e5-47bd-92b6-035f2226f29e.png)

# %%
# This is a simple arithmetic expression to multiply then add integers

(3*4)+5
# Out:
# 17

# %% [markdown]
# Exercise 9: ![Ex. 9.png](attachment:18f1a701-b809-4629-b8a7-b1a9e6d6bbb8.png)

# %%
# This will convert 200 minutes to hours by diving by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# Exercise 11: ![Ex. 11.png](attachment:40f1a41c-8069-413c-bc4f-c2f3164e8622.png)

# %% [markdown]
# ## Author:
# Oliver Quevedo Rodríguez.
